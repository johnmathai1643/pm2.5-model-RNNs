# %%
import lstm
import time
import matplotlib.pyplot as plt
import numpy as np
import os
import math
import sys
import pandas as pd
from pandas import Series, DataFrame, Panel
import keras
from keras.callbacks import ModelCheckpoint
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, Normalizer
from sklearn.model_selection import train_test_split
import re
from datetime import datetime
from sklearn.metrics import mean_squared_error
from scipy.stats import logistic
# %matplotlib inline
# Get current size
fig_size = plt.rcParams["figure.figsize"]
 
# Prints: [8.0, 6.0]
print ("Current size:", fig_size)
 
# Set figure width to 12 and height to 9
fig_size[0] = 24
fig_size[1] = 18
plt.rcParams["figure.figsize"] = fig_size
keras.backend.image_dim_ordering()
# Out:
# Using TensorFlow backend.
# Current size: [6.0, 4.0]
# 'tf'

# %%
class BatchGenerator:
    
    def __init__(self, file, time_steps=48, scaler_type='standard', pca=False, pca_dim=8, normal=False):
        self.file = file
        self.time_steps = time_steps
        self.scaler_type = scaler_type
        self.pca = pca
        self.pca_dim = pca_dim
        self.normal = normal
        
        print ("Loading data ...")
        data_loaded = pd.read_pickle(self.file)
        data_loaded.isnull().sum()
        
        # load data
        data_loaded_np = data_loaded[["PM2.5","WS","RH","BP","VWS","SR","WD","TEMP"]].as_matrix()
        
        # Standardization of output pm25 only
#         pm25_ori = data_loaded_np[0:,0]
#         print(np.shape(pm25_ori))
#         pm25_ori = pm25_ori.reshape((len(pm25_ori), 1))
#         self.scale_output = StandardScaler()
#         pm25_ori = self.scale_output.fit_transform(pm25_ori)
#         print(np.shape(pm25_ori))
#         pm25_ori = pm25_ori.reshape(-1)
#         self.X_norm_ori_pm, self.y_norm_ori_pm = self.generate_batch_data(pm25_ori, time_steps=self.time_steps, name="pm25_ori")
        
        # Standardization of complete dataset
#         data_loaded_np = self.scaler.fit_transform(data_loaded_np)
       
        # PCA
        if self.pca == True:
            print("PCA transform")
            pca = PCA(n_components=self.pca_dim, svd_solver='full')
            pca = pca.fit(data_loaded_np)
            data_loaded_np = pca.transform(data_loaded_np)
        
        #Row Normalization    
        if self.normal == True:
            print("Normalize transform")
            self.norm_scaler = Normalizer().fit(data_loaded_np)
            data_loaded_np = self.norm_scaler.transform(data_loaded_np)

        self.X_norm_pm, self.y_norm_pm, self.scaler_pm = self.generate_batch_data(data_loaded_np[0:,0], time_steps=self.time_steps, name="pm25")
        self.X_norm_ws, self.y_norm_ws, self.scaler_ws = self.generate_batch_data(data_loaded_np[0:,1], time_steps=self.time_steps, name="ws")
        self.X_norm_rh, self.y_norm_rh, self.scaler_rh = self.generate_batch_data(data_loaded_np[0:,2], time_steps=self.time_steps, name="rh")
        self.X_norm_bp, self.y_norm_bp, self.scaler_bp = self.generate_batch_data(data_loaded_np[0:,3], time_steps=self.time_steps, name="bp")
        self.X_norm_vws, self.y_norm_vws, self.scaler_vws = self.generate_batch_data(data_loaded_np[0:,4], time_steps=self.time_steps, name="vws")
        self.X_norm_sr, self.y_norm_sr, self.scaler_sr = self.generate_batch_data(data_loaded_np[0:,5], time_steps=self.time_steps, name="sr")
        self.X_norm_wd, self.y_norm_wd, self.scaler_wd = self.generate_batch_data(data_loaded_np[0:,6], time_steps=self.time_steps, name="wd")
        self.X_norm_temp, self.y_norm_temp, self.scaler_temp = self.generate_batch_data(data_loaded_np[0:,7], time_steps=self.time_steps, name="temp")

        if not (self.scaler_type is None):
            filename = "np_"+self.scaler_type+"_process_comp_"+str(self.time_steps)+"_"+str(self.pca)+"_"+str(self.normal)+".npz"
        else:
            filename = "np_process_comp_"+str(self.time_steps)+"_"+str(self.pca)+"_"+str(self.normal)+".npz"

        if os.path.isfile("data_log/"+filename):
            print ("Found existing file :","data_log/"+filename)
            print ("Loading ...")
            npzfile = np.load("data_log/"+filename)
            self.X_norm_pm = npzfile['arr_0']
            self.X = npzfile['arr_1']
            self.Y = npzfile['arr_2']
            print ("Complete.")
        else:
            self.X = np.array(np.zeros([1, 7]))
            for i in range(len(self.X_norm_pm)):
                temp = np.column_stack((self.X_norm_ws[i],self.X_norm_rh[i],self.X_norm_bp[i],self.X_norm_vws[i],self.X_norm_sr[i],self.X_norm_wd[i],self.X_norm_temp[i]))
                self.X = np.append(self.X, temp, axis=0)

            self.X = self.X[1:].reshape(len(self.X_norm_pm),48,7)
#             self.Y = self.y_norm_ori_pm
            self.Y = self.y_norm_pm 

            print ("Input shape :",np.shape(self.X_norm_pm))
            print ("Aux Input shape :",np.shape(self.X))
            print ("Output shape :",np.shape(self.Y))
            print ("Saving file ...")
            np.savez("data_log/"+filename, self.X_norm_pm, self.X, self.Y)
            print ("Saved file to :", filename)
            print ("Complete.")
        
    def return_data(self):
        return self.X_norm_pm, self.X, self.Y, self.scaler_pm

    def shift(self, arr, num, fill_value=np.nan):
        result = np.empty_like(arr)
        if num > 0:
            result[:num] = fill_value
            result[num:] = arr[:-num]
        elif num < 0:
            result[num:] = fill_value
            result[:num] = arr[-num:]
        else:
            result = arr
        return result

    def generate_batch_data(self, raw_data, time_steps, name):
        series = pd.Series(raw_data, dtype=np.float32)
        values = series.values
        values = values.reshape((len(values), 1))
        print('feature ------------ ', name.upper())
        
        if self.scaler_type == 'standard':
            scaler = StandardScaler()
        if self.scaler_type == 'robust':
            scaler = RobustScaler()
        if self.scaler_type == 'min_max':
            scaler = MinMaxScaler(feature_range=(0, 1))
            
        scaler = scaler.fit(values)
        normalized = scaler.transform(values)
        
        #data = values
        data = normalized
        print('Max: %f, Min: %f' % (np.amax(data), np.amin(data)))
        x = data[:(len(data)-(len(data) % time_steps))]
        y = self.shift(data,-(time_steps)).astype(np.float32)

        x_batches = np.array([])
        y_batches = np.array([])

        # check if file exists
        if (self.scaler_type is None):
            seq_file_name = "np_processed_"+name+"_"+str(time_steps)+"_"+str(self.pca)+"_"+str(self.normal)+".npz"
        else:
            seq_file_name = "np_"+self.scaler_type+"_processed_"+name+"_"+str(time_steps)+"_"+str(self.pca)+"_"+str(self.normal)+".npz"          

        if os.path.isfile("data_log/"+seq_file_name):
            npzfile = np.load("data_log/"+seq_file_name)
            x_batches = npzfile['arr_0']
            y_batches = npzfile['arr_1']
            return x_batches, y_batches, scaler
        else: 
            for i in range(len(y)):
                try:
                    x_batches = np.append(x_batches, x[i:i+(time_steps)].reshape(-1,12,1))
                    y_batches = np.append(y_batches, y[i].reshape(-1))
                except ValueError:
                    break
                    
            x_batches = x_batches.reshape(-1, time_steps, 1)
            y_batches = y_batches.reshape(-1)
            np.savez("data_log/"+seq_file_name, x_batches, y_batches)
            return x_batches, y_batches, scaler

# %%
if __name__=='__main__':
    global_start_time = time.time()
    startTime = datetime.now() 
    epochs  = 150
    state_neurons_1 = 1024
    state_neurons_2 = 1024
    state_neurons_3 = 1024
    output = 1
    seed = 7
    batch_size = 32
    scaler_type="standard"
    dropouts = [0.15, 0.25, 0.45]
    seq_len = 48
    
    
    batch_generator_obj = BatchGenerator(file="data_log/mumbai_6_log_pro.pkl", time_steps=48, scaler_type=scaler_type, pca=False, pca_dim=8, normal=False)
    X_norm, X_aux_norm, y_norm, scaler = batch_generator_obj.return_data()
    X_train, X_val, X_aux_train, X_aux_val, y_train, y_val = train_test_split(X_norm, X_aux_norm, y_norm, test_size=0.20, random_state=seed)
#     X_val, X_test, X_aux_val, X_aux_test, y_val, y_test = train_test_split(X_val, X_aux_val, y_val, test_size=0.50, random_state=seed)
    
    print('> Data Loaded. Compiling...')
    model = lstm.build_model([4, 7], [7, seq_len, state_neurons_1, state_neurons_2, output], dropouts)
    
    file_name = "wt_LSTM_Keras_tanh_rmsprop_"+scaler_type+"_dp("+"_".join(str(x) for x in dropouts)+")_"+str(epochs)+"_"+str(seq_len)+"_"+str(state_neurons_1)+"_"+str(state_neurons_1)+"_"+str(state_neurons_1)+"_"+str(batch_size)
    checkpoint = ModelCheckpoint(file_name+".h5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')
    callbacks_list = [checkpoint]

    mod_hist = model.fit([X_train, X_aux_train], [y_train], validation_data=([X_val, X_aux_val], [y_val]), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list, shuffle=True)

    print('Training duration (s) : ', time.time() - global_start_time)
    print('Training duration (Hr) : ', datetime.now() - startTime)
    
    file = "LSTM_Keras_linear_rmsprop_"+scaler_type+"_dp("+"_".join(str(x) for x in dropouts)+")_"+str(epochs)+"_"+str(seq_len)+"_"+str(state_neurons_1)+"_"+str(state_neurons_1)+"_"+str(state_neurons_1)+"_"+str(batch_size)
    print("Saving model : "+file+".h5")
    model.save(file+".h5")
    print("Model saved...")
# Out:
# Loading data ...
# feature ------------  PM25
# Max: 3.284291, Min: -10.752898
# feature ------------  WS
# Max: 3.415116, Min: -2.449860
# feature ------------  RH
# Max: 1.363076, Min: -4.063657
# feature ------------  BP
# Max: 5.360242, Min: -7.499539
# feature ------------  VWS
# Max: 9.401879, Min: -11.963299
# feature ------------  SR
# Max: 1.637784, Min: -2.654759
# feature ------------  WD
# Max: 1.076242, Min: -6.484889
# feature ------------  TEMP
# Max: 3.006956, Min: -3.982146
# Found existing file : data_log/np_standard_process_comp_48_False_False.npz
# Loading ...
# Complete.
# > Data Loaded. Compiling...
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 48, 1)        0
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 48, 1)        2           main_input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 48, 1)        4           time_distributed_1[0][0]
# __________________________________________________________________________________________________
# cu_dnnlstm_1 (CuDNNLSTM)        (None, 48, 1024)     4206592     batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 48, 1024)     0           cu_dnnlstm_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 48, 1024)     4096        dropout_1[0][0]
# __________________________________________________________________________________________________
# cu_dnnlstm_2 (CuDNNLSTM)        (None, 48, 1024)     8396800     batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 48, 1024)     0           cu_dnnlstm_2[0][0]
# __________________________________________________________________________________________________
# aux_input (InputLayer)          (None, 48, 7)        0
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 48, 1024)     4096        dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 48, 7)        28          aux_input[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 48, 2048)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 48, 4)        32          batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# cu_dnnlstm_3 (CuDNNLSTM)        (None, 48, 1024)     12591104    concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 48, 4)        16          time_distributed_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 48, 1024)     0           cu_dnnlstm_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_3 (TimeDistrib (None, 48, 7)        35          batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 48, 1024)     4096        dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 48, 7)        28          time_distributed_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 48, 1031)     0           batch_normalization_4[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 48, 1031)     4124        concatenate_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (None, 48, 512)      528384      batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 48, 512)      2048        time_distributed_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_5 (TimeDistrib (None, 48, 1)        513         batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 48, 1)        4           time_distributed_5[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 48)           0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            49          flatten_1[0][0]
# ==================================================================================================
# Total params: 25,742,051
# Trainable params: 25,732,781
# Non-trainable params: 9,270
# __________________________________________________________________________________________________
# None
# > Compilation Time :  0.03409075736999512
# Train on 15706 samples, validate on 3927 samples
# Epoch 1/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 1.1714Epoch 00000: val_loss improved from inf to 1.20087, saving model to wt_LSTM_Keras_tanh_rmsprop_standard_dp(0.15_0.25_0.45)_150_48_1024_1024_1024_32.h5
# 15706/15706 [==============================] - ETA: 0s - loss: 1.1704 - val_loss: 1.2009
# Epoch 2/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.9812Epoch 00001: val_loss improved from 1.20087 to 0.88307, saving model to wt_LSTM_Keras_tanh_rmsprop_standard_dp(0.15_0.25_0.45)_150_48_1024_1024_1024_32.h5
# 15706/15706 [==============================] - ETA: 0s - loss: 0.9806 - val_loss: 0.8831
# Epoch 3/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.7342Epoch 00002: val_loss improved from 0.88307 to 0.78440, saving model to wt_LSTM_Keras_tanh_rmsprop_standard_dp(0.15_0.25_0.45)_150_48_1024_1024_1024_32.h5
# 15706/15706 [==============================] - ETA: 0s - loss: 0.7368 - val_loss: 0.7844
# Epoch 4/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.7129Epoch 00003: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.7130 - val_loss: 0.8662
# Epoch 5/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.6884Epoch 00004: val_loss improved from 0.78440 to 0.66955, saving model to wt_LSTM_Keras_tanh_rmsprop_standard_dp(0.15_0.25_0.45)_150_48_1024_1024_1024_32.h5
# 15706/15706 [==============================] - ETA: 0s - loss: 0.6880 - val_loss: 0.6695
# Epoch 6/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.6272Epoch 00005: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.6267 - val_loss: 1.0026
# Epoch 7/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.5226Epoch 00006: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.5225 - val_loss: 1.2484
# Epoch 8/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.4644Epoch 00007: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.4653 - val_loss: 1.1113
# Epoch 9/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.4408Epoch 00008: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.4405 - val_loss: 1.2856
# Epoch 10/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.4331Epoch 00009: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.4330 - val_loss: 1.0700
# Epoch 11/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.4205Epoch 00010: val_loss improved from 0.66955 to 0.49787, saving model to wt_LSTM_Keras_tanh_rmsprop_standard_dp(0.15_0.25_0.45)_150_48_1024_1024_1024_32.h5
# 15706/15706 [==============================] - ETA: 0s - loss: 0.4206 - val_loss: 0.4979
# Epoch 12/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.4050Epoch 00011: val_loss improved from 0.49787 to 0.36464, saving model to wt_LSTM_Keras_tanh_rmsprop_standard_dp(0.15_0.25_0.45)_150_48_1024_1024_1024_32.h5
# 15706/15706 [==============================] - ETA: 0s - loss: 0.4047 - val_loss: 0.3646
# Epoch 13/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3560Epoch 00012: val_loss improved from 0.36464 to 0.28649, saving model to wt_LSTM_Keras_tanh_rmsprop_standard_dp(0.15_0.25_0.45)_150_48_1024_1024_1024_32.h5
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3557 - val_loss: 0.2865
# Epoch 14/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3392Epoch 00013: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3392 - val_loss: 0.4105
# Epoch 15/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3286Epoch 00014: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3284 - val_loss: 1.0253
# Epoch 16/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3303Epoch 00015: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3301 - val_loss: 0.3870
# Epoch 17/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3215Epoch 00016: val_loss improved from 0.28649 to 0.27428, saving model to wt_LSTM_Keras_tanh_rmsprop_standard_dp(0.15_0.25_0.45)_150_48_1024_1024_1024_32.h5
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3212 - val_loss: 0.2743
# Epoch 18/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3221Epoch 00017: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3228 - val_loss: 0.8124
# Epoch 19/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3213Epoch 00018: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3211 - val_loss: 0.3271
# Epoch 20/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3206Epoch 00019: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3218 - val_loss: 1.1984
# Epoch 21/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3192Epoch 00020: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3192 - val_loss: 0.3215
# Epoch 22/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3190Epoch 00021: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3187 - val_loss: 0.3584
# Epoch 23/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3138Epoch 00022: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3135 - val_loss: 0.4217
# Epoch 24/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3149Epoch 00023: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3146 - val_loss: 0.3261
# Epoch 25/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3107Epoch 00024: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3108 - val_loss: 0.3026
# Epoch 26/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3125Epoch 00025: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3128 - val_loss: 0.4810
# Epoch 27/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3159Epoch 00026: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3160 - val_loss: 0.4863
# Epoch 28/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3092Epoch 00027: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3096 - val_loss: 0.7244
# Epoch 29/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3098Epoch 00028: val_loss improved from 0.27428 to 0.27221, saving model to wt_LSTM_Keras_tanh_rmsprop_standard_dp(0.15_0.25_0.45)_150_48_1024_1024_1024_32.h5
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3096 - val_loss: 0.2722
# Epoch 30/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3084Epoch 00029: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3082 - val_loss: 0.2783
# Epoch 31/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3101Epoch 00030: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3115 - val_loss: 0.4261
# Epoch 32/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3075Epoch 00031: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3074 - val_loss: 0.2761
# Epoch 33/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3106Epoch 00032: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3113 - val_loss: 0.3526
# Epoch 34/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3122Epoch 00033: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3120 - val_loss: 0.2931
# Epoch 35/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3088Epoch 00034: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3096 - val_loss: 0.2794
# Epoch 36/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3105Epoch 00035: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3102 - val_loss: 0.3765
# Epoch 37/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3112Epoch 00036: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3112 - val_loss: 0.2858
# Epoch 38/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3057Epoch 00037: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3057 - val_loss: 0.3229
# Epoch 39/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3066Epoch 00038: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3065 - val_loss: 0.3731
# Epoch 40/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3093Epoch 00039: val_loss improved from 0.27221 to 0.27112, saving model to wt_LSTM_Keras_tanh_rmsprop_standard_dp(0.15_0.25_0.45)_150_48_1024_1024_1024_32.h5
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3094 - val_loss: 0.2711
# Epoch 41/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3073Epoch 00040: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3072 - val_loss: 0.2955
# Epoch 42/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3062Epoch 00041: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3059 - val_loss: 0.4306
# Epoch 43/150
# 15680/15706 [============================>.] - ETA: 44s - loss: 0.3033Epoch 00042: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3039 - val_loss: 0.2733
# Epoch 44/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3048Epoch 00043: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3046 - val_loss: 0.3436
# Epoch 45/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3058Epoch 00044: val_loss improved from 0.27112 to 0.26571, saving model to wt_LSTM_Keras_tanh_rmsprop_standard_dp(0.15_0.25_0.45)_150_48_1024_1024_1024_32.h5
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3057 - val_loss: 0.2657
# Epoch 46/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3032Epoch 00045: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3030 - val_loss: 0.3381
# Epoch 47/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3073Epoch 00046: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3070 - val_loss: 0.2832
# Epoch 48/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3005Epoch 00047: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3005 - val_loss: 0.2744
# Epoch 49/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3016Epoch 00048: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3013 - val_loss: 0.2764
# Epoch 50/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3061Epoch 00049: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3060 - val_loss: 0.3120
# Epoch 51/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3009Epoch 00050: val_loss improved from 0.26571 to 0.26474, saving model to wt_LSTM_Keras_tanh_rmsprop_standard_dp(0.15_0.25_0.45)_150_48_1024_1024_1024_32.h5
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3012 - val_loss: 0.2647
# Epoch 52/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.2999Epoch 00051: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3002 - val_loss: 0.3092
# Epoch 53/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3007Epoch 00052: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3009 - val_loss: 0.2712
# Epoch 54/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3027Epoch 00053: val_loss improved from 0.26474 to 0.26091, saving model to wt_LSTM_Keras_tanh_rmsprop_standard_dp(0.15_0.25_0.45)_150_48_1024_1024_1024_32.h5
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3029 - val_loss: 0.2609
# Epoch 55/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.2999Epoch 00054: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.2996 - val_loss: 0.3061
# Epoch 56/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3027Epoch 00055: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3025 - val_loss: 0.2665
# Epoch 57/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3060Epoch 00056: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3057 - val_loss: 0.3147
# Epoch 58/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3022Epoch 00057: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3021 - val_loss: 0.3419
# Epoch 59/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3045Epoch 00058: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3044 - val_loss: 0.4402
# Epoch 60/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3041Epoch 00059: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3038 - val_loss: 0.3060
# Epoch 61/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3013Epoch 00060: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3009 - val_loss: 0.2824
# Epoch 62/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3066Epoch 00061: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3068 - val_loss: 0.2815
# Epoch 63/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3059Epoch 00062: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3057 - val_loss: 0.3061
# Epoch 64/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3006Epoch 00063: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3007 - val_loss: 0.4114
# Epoch 65/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3036Epoch 00064: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3033 - val_loss: 0.3134
# Epoch 66/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3053Epoch 00065: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3053 - val_loss: 0.3090
# Epoch 67/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3010Epoch 00066: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3020 - val_loss: 0.2740
# Epoch 68/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3033Epoch 00067: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3032 - val_loss: 0.2920
# Epoch 69/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.2995Epoch 00068: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.2993 - val_loss: 0.2813
# Epoch 70/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3040Epoch 00069: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3039 - val_loss: 0.2968
# Epoch 71/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3005Epoch 00070: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3003 - val_loss: 0.2699
# Epoch 72/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3041Epoch 00071: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3037 - val_loss: 0.3104
# Epoch 73/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3012Epoch 00072: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3012 - val_loss: 0.2789
# Epoch 74/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3012Epoch 00073: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3009 - val_loss: 0.5626
# Epoch 75/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3009Epoch 00074: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3009 - val_loss: 0.3505
# Epoch 76/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3027Epoch 00075: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3033 - val_loss: 0.2800
# Epoch 77/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3011Epoch 00076: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3013 - val_loss: 0.3011
# Epoch 78/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3022Epoch 00077: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3021 - val_loss: 0.3323
# Epoch 79/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3020Epoch 00078: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3034 - val_loss: 0.2870
# Epoch 80/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3042Epoch 00079: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3043 - val_loss: 0.3284
# Epoch 81/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3037Epoch 00080: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3038 - val_loss: 0.2747
# Epoch 82/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.2982Epoch 00081: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.2986 - val_loss: 0.2705
# Epoch 83/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3002Epoch 00082: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3007 - val_loss: 0.3258
# Epoch 84/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3044Epoch 00083: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3041 - val_loss: 0.2677
# Epoch 85/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3020Epoch 00084: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3020 - val_loss: 0.2800
# Epoch 86/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3030Epoch 00085: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3028 - val_loss: 0.3156
# Epoch 87/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3024Epoch 00086: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3024 - val_loss: 0.2792
# Epoch 88/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3037Epoch 00087: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3035 - val_loss: 0.2721
# Epoch 89/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3021Epoch 00088: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3017 - val_loss: 0.3596
# Epoch 90/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3017Epoch 00089: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3019 - val_loss: 0.2765
# Epoch 91/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3036Epoch 00090: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3035 - val_loss: 0.2866
# Epoch 92/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3018Epoch 00091: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3016 - val_loss: 0.3264
# Epoch 93/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3023Epoch 00092: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3023 - val_loss: 0.2847
# Epoch 94/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.2996Epoch 00093: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.2994 - val_loss: 0.2736
# Epoch 95/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3055Epoch 00094: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3054 - val_loss: 0.3437
# Epoch 96/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3032Epoch 00095: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3029 - val_loss: 0.2983
# Epoch 97/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.2997Epoch 00096: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.2996 - val_loss: 0.2948
# Epoch 98/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3046Epoch 00097: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3043 - val_loss: 0.2707
# Epoch 99/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3045Epoch 00098: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3046 - val_loss: 0.2964
# Epoch 100/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3022Epoch 00099: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3019 - val_loss: 0.3043
# Epoch 101/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3011Epoch 00100: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3010 - val_loss: 0.2834
# Epoch 102/150
# 15680/15706 [============================>.] - ETA: 0s - loss: 0.3027Epoch 00101: val_loss did not improve
# 15706/15706 [==============================] - ETA: 0s - loss: 0.3026 - val_loss: 0.2689
# Epoch 103/150
#   480/15706 [..............................] - ETA: 106s - loss: 0.5752

# %%
if __name__=='__main__':
    #predict sequence
    _y_norm = lstm.predict_point_by_point_aux(model, [X_norm, X_aux_norm])
    _y_train = lstm.predict_point_by_point_aux(model, [X_train, X_aux_train])
    _y_val = lstm.predict_point_by_point_aux(model, [X_val, X_aux_val])
#     _y_test = lstm.predict_point_by_point_aux(model,  [X_test, X_aux_test])

# %%
if __name__=='__main__':
    _y_norm = _y_norm.reshape(-1,1)
    _y_train = _y_train.reshape(-1,1)
    _y_val = _y_val.reshape(-1,1)
#     _y_test = _y_test.reshape(-1,1)
    
    y_norm = y_norm.reshape(-1,1)
    y_train = y_train.reshape(-1,1)
    y_val = y_val.reshape(-1,1)
#     y_test = y_test.reshape(-1,1)
    
    print("Predicted Output shape: ", np.shape(_y_norm))
    print("Original Output shape:  ", np.shape(y_norm))
    
    #inverse the predictions to its actual value
    print("Predicted Output sample: ")
    _y = scaler.inverse_transform(_y_norm)
    _y_tr = scaler.inverse_transform(_y_train)
    _y_va = scaler.inverse_transform(_y_val)
#     _y_te = scaler.inverse_transform(_y_test)
    for i in range(5):
        print(_y_va[i])
    
    #inverse the outputs to its actual value
    print("Original Output sample: ")
    y = scaler.inverse_transform(y_norm)
    y_tr = scaler.inverse_transform(y_train)
    y_va = scaler.inverse_transform(y_val)
#     y_te = scaler.inverse_transform(y_test)
    for i in range(5):
        print(y_va[i])    
    
    #predicted
    _Y = pd.Series(np.ravel(_y))
    _Y_TR = pd.Series(np.ravel(_y_tr))
    _Y_VA = pd.Series(np.ravel(_y_va))
#     _Y_TE = pd.Series(np.ravel(_y_te))
    
    #original
    Y =  pd.Series(np.ravel(y))
    Y_TR = pd.Series(np.ravel(y_tr))
    Y_VA = pd.Series(np.ravel(y_va))
#     Y_TE = pd.Series(np.ravel(y_te))

# %%
if __name__=='__main__':
    print('Total RMSE :', math.sqrt(mean_squared_error(_Y, Y)))
    print('Training RMSE :', math.sqrt(mean_squared_error(_Y_TR, Y_TR)))
    print('Validation RMSE :', math.sqrt(mean_squared_error(_Y_VA, Y_VA)))
#     print('Test RMSE :', math.sqrt(mean_squared_error(_Y_TE, Y_TE)))
    
    plot_predicted, = plt.plot(_Y_VA[100:300], label='predicted')
    plot_train, = plt.plot(Y_VA[100:300], label='actual')
    plt.legend(handles=[plot_predicted, plot_train])

# %%
# summarize history for loss
plt.plot(mod_hist.history['loss'])
plt.plot(mod_hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
if __name__=='__main__':
    #recreate model 
    model = lstm.build_model([4, 7], [7, seq_len, state_neurons_1, state_neurons_2, output], dropouts, pre_train=file_name+".h5")
    print("Created model and loaded weights from "+file_name+".h5")
    
    # estimate accuracy on whole dataset using loaded weights
    _y_val = lstm.predict_point_by_point_aux(model, [X_val, X_aux_val])
#     _y_test = lstm.predict_point_by_point_aux(model,  [X_test, X_aux_test])
    
    _y_val = _y_val.reshape(-1,1)
#     _y_test = _y_test.reshape(-1,1)
    
    y_val = y_val.reshape(-1,1)
#     y_test = y_test.reshape(-1,1)
    
    #inverse the predictions to its actual value
    print("Predicted Output sample: ")
    _y_va = scaler.inverse_transform(_y_val)
#     _y_te = scaler.inverse_transform(_y_test)
    for i in range(5):
        print(_y_va[i])
    
    #inverse the outputs to its actual value
    print("Original Output sample: ")
    y_va = scaler.inverse_transform(y_val)
#     y_te = scaler.inverse_transform(y_test)
    for i in range(5):
        print(y_va[i])    
    
    
    y_va = np.exp(y_va)
    _y_va = np.exp(_y_va)
    
    #predicted
    _Y_VA = pd.Series(np.ravel(_y_va))
#     _Y_TE = pd.Series(np.ravel(_y_te))
    
    #original
    Y_VA = pd.Series(np.ravel(y_va))
#     Y_TE = pd.Series(np.ravel(y_te))
    
    print('Validation RMSE :', math.sqrt(mean_squared_error(_Y_VA, Y_VA)))
#     print('Test RMSE :', math.sqrt(mean_squared_error(_Y_TE, Y_TE)))
    
    plot_predicted, = plt.plot(_Y_VA[100:300], label='predicted')
    plot_train, = plt.plot(Y_VA[100:300], label='actual')
    plt.legend(handles=[plot_predicted, plot_train])

# %%
def squash(x):
    return float(1.0 * x/(x+10))
